# %% [markdown]
# ### Preparing the data:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Modules:

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.layers as tkl
import tensorflow as tf
from keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Input, Conv2D, UpSampling2D, BatchNormalization, Activation, Add, ZeroPadding2D, concatenate
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import cv2
from sklearn.model_selection import train_test_split
from skimage.util import random_noise
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import glob
import random
from itertools import chain

# %% [markdown]
# ### Creating a list of file names:

# %%
source_path = '/content/drive/MyDrive/HighResolution/'

filenames = []
folder_names = ['62000', '63000', '64000', '65000', '66000', '67000', '68000', '69000']
# test = os.path.join(source_path, f'{folder_names[1]}')
# content = os.listdir(test)

# print(content)
for folder in folder_names:
  
    filenames.append(glob.glob(os.path.join(source_path, f'{folder}/*.png')))

filenames = list(chain.from_iterable(filenames))
random.shuffle(filenames)
print('Completed.')
# Out:
# Completed.

# %% [markdown]
# ### Length of filenames:

# %%
print(len(filenames))
# Out:
# 8000

# %% [markdown]
# ### Showing a sample:

# %%
img_path = filenames[1001]
print(img_path)
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (500, 500))
noisy = random_noise(img, mode = 's&p', amount=0.05)
fig, ax = plt.subplots(1, 2, figsize = (10,12))
ax[0].imshow(img)
ax[0].set_title('Original')
ax[1].imshow(noisy)
ax[1].set_title('Noisy')
# Out:
# /content/drive/MyDrive/HighResolution/65000/65004.png
# Text(0.5, 1.0, 'Noisy')

# %% [markdown]
# ### Creating train set and test set:

# %%
test_filenames = filenames[-2001:-1]
del filenames[-2001:-1]
train_filenames = filenames
print(f'Size of training set is: {len(train_filenames)}', end='\n----------------------------\n')
print(f'Size of test set is: {len(test_filenames)}', end='\n----------------------------\n')
# Out:
# Size of training set is: 6000
# ----------------------------
# Size of test set is: 2000
# ----------------------------

# %% [markdown]
# ### Train set and validation set:

# %%
train_img, val_img, _, _ = train_test_split(train_filenames, train_filenames, test_size = 0.2, shuffle = True, random_state = 0)

# %%
print(f'Size of training set is: {len(train_img)}', end='\n----------------------------\n')
print(f'Size of validation set is: {len(val_img)}', end='\n----------------------------\n')
print(f'Total: {len(train_img) + len(val_img)}')
# Out:
# Size of training set is: 4800
# ----------------------------
# Size of validation set is: 1200
# ----------------------------
# Total: 6000

# %% [markdown]
# ### Determining important variables:

# %%
WIDTH = 512
HEIGHT = 512
n_channels = 3
BATCH_SIZE = 32

# %% [markdown]
# ### Data generation:

# %%
class  DataGenerator(tf.keras.utils.Sequence):
    
    def __init__(self, orig_filenames, batch_size = 32, shuffle = True):
        self.orig_filenames = orig_filenames
        self.noisy_filenames = orig_filenames
        self.filenames = list(zip(self.orig_filenames, self.noisy_filenames))
        self.batch_size = BATCH_SIZE
        self.shuffle = shuffle
    
    def __len__(self):
        return (len(self.orig_filenames) // self.batch_size)
    
    def __getitem__(self, idx):
        batch = self.filenames[idx * self.batch_size : (idx + 1) * self.batch_size]
        X, Y = self.__data_generation(batch)

        return X, Y
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.orig_filenames))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def __data_generation(self, batch):
        orig = []
        noisy = []
        
        for orig_file, _ in batch:
          image = cv2.imread(orig_file)
          image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          image = cv2.resize(image, (WIDTH, HEIGHT))
          # image_orig = cv2.resize(image, (256,256))
          # image_orig = tf.expand_dims(image_orig, axis=0)
          # print(f'noisy set shape: {image_noisy.shape} ... orig set shape: {image_orig.shape}')
          orig.append(image)
          noisy.append(self.make_noisy(image))
          
        return  np.array(noisy), np.array(orig)

    def make_noisy(self, image):
      image_ = image
      noisy_image = random_noise(image_, mode = 's&p', amount=0.05)
      
      return noisy_image

# %% [markdown]
# ### Generating training set and validation set:

# %%
train_generator = DataGenerator(train_img, BATCH_SIZE)
val_generator = DataGenerator(val_img, BATCH_SIZE)

# %% [markdown]
# ### Creating the model architecture (U-net):

# %%
def resnet(input= None, n_filters=64, kernel_size=(3,3), padding='same', stride=1):
    pad = ZeroPadding2D((3,3))(input)
    conv = Conv2D(16, (7,7), strides=2)(pad)
    # conv = Activation('relu')(conv)
    # conv = BatchNormalization()(conv)
    skip0 = conv    #256,256,16
    print(f'Skip0 dimensions is: {skip0}')
    # conv = ZeroPadding2D((1,1))(conv)
    out0 = MaxPooling2D(pool_size=(2,2), strides=2)(conv)   # 128,128,16
    print(f'out0 dimensions is: {out0}')

    # -------

    # block1:
    conv = ZeroPadding2D((1,1))(out0)
    conv = Conv2D(16, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(16, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv)
    # out0 = Conv2D(32, padding='same')
    out1 = Add()([conv, out0])    # 128,128,16
    print(f'out1 dimensions is: {out1}')

    conv = ZeroPadding2D((1,1))(out1)
    conv = Conv2D(32, (3,3), strides=1)(conv) #128,128,32
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(32, (3,3), strides=1)(conv) #128,128,32
    # print('convvv', conv)
    # conv = BatchNormalization()(conv)
    # out1 = Conv2D(32, (3,3), padding='same')(out1)
    temp_out = Conv2D(32, (1,1), padding='same')(out1)   
    print('shape of temp out: ', temp_out)
    out = Add()([conv, temp_out]) 
    skip1 = out       # #128,128,32
    print(f'Skip1 dimensions is: {skip1}')
    out2 = MaxPooling2D(pool_size=(2,2), strides=2)(out) #64, 64, 32
    print(f'out2 dimensions is: {out2}')

    # block3

    conv = ZeroPadding2D((1,1))(out2)
    conv = Conv2D(32, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(32, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv) 
    out3 = Add()([conv, out2])     #64, 64, 32
    print(f'out3 dimensions is: {out3}')


    conv = ZeroPadding2D((1,1))(out3)
    conv = Conv2D(64, (3,3), strides=1)(conv) 
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(64, (3,3), strides=1)(conv)   #64, 64, 64
    # conv = BatchNormalization()(conv)
    temp_out = Conv2D(64, (1,1), padding='same')(out3)   #64, 64, 64
    out = Add()([conv, temp_out])
    skip2 = out     # 64, 64, 64
    print(f'Skip2 dimensions is: {skip2}')
    out4 = MaxPooling2D(pool_size=(2,2), strides=2)(out)  # 32, 32, 64
    print(f'out8 dimensions is: {out4}')


    # block4

    conv = ZeroPadding2D((1,1))(out4)
    conv = Conv2D(64, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(64, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv) 
    out5 = Add()([conv, out4])     # 32,32,64
    print(f'out5 dimensions is: {out5}')


    conv = ZeroPadding2D((1,1))(out5)
    conv = Conv2D(128, (3,3), strides=1)(conv) 
    print('convvv', conv)
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(128, (3,3), strides=1)(conv)   # 32,32,128
    conv = BatchNormalization()(conv)
    temp_out = Conv2D(128, (1,1), padding='same')(out5)   #32,32,128
    out = Add()([conv, temp_out])
    skip3 = out     #32,32,128
    print(f'Skip3 dimensions is: {skip3}')
    out6 = MaxPooling2D(pool_size=(2,2), strides=2)(out)  # 32, 32, 64
    print(f'out6 dimensions is: {out6}')

    # block5

    conv = ZeroPadding2D((1,1))(out6)
    conv = Conv2D(128, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(128, (3,3), strides=1)(conv)
    # conv = BatchNormalization()(conv) 
    out7 = Add()([conv, out6])     # 16,16,128
    print(f'out7 dimensions is: {out7}')


    conv = ZeroPadding2D((1,1))(out7)
    conv = Conv2D(256, (3,3), strides=1)(conv) 
    # conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(256, (3,3), strides=1)(conv)   # 16,16,256
    # conv = BatchNormalization()(conv)
    temp_out = Conv2D(256, (1,1), padding='same')(out7)   # 16,16,256
    out = Add()([conv, temp_out])
    skip4 = out     # 16,16,256
    print(f'Skip4 dimensions is: {skip4}')
    out8 = MaxPooling2D(pool_size=(2,2), strides=2)(out)  # 8,8,256
    print(f'out8 dimensions is: {out8}')




    # conv = BatchNormalization()(out15)
    conv = Activation('relu')(out8) 

    # print(out16)
    # conv = tkl.Dropout(0.2)(conv)
    # conv = BatchNormalization()(out16)    
    # skip3 = conv    # 16, 16, 256
    # print(f'Skip3 dimensions is: {skip3}')
    # conv = ZeroPadding2D((1,1))(conv)
    conv = Conv2D(256, (3,3), padding='same')(conv)
    # conv = Activation('relu')(conv) 
    # conv = Conv2D(256, (3,3), padding='same')(conv)
    conv = Activation('relu')(conv)     # 8, 8, 256
    print(f'Connnnnnnnnnv: {conv}')

    return skip0, skip1, skip2, skip3, skip4, conv


input_shape = (WIDTH, HEIGHT, n_channels)
input_img = Input(input_shape, name='image')
skip0, skip1, skip2, skip3, skip4, conv = resnet(input_img)
# Out:
# Skip0 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 16), dtype=tf.float32, name=None), name='conv2d_114/BiasAdd:0', description="created by layer 'conv2d_114'")
# out0 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 16), dtype=tf.float32, name=None), name='max_pooling2d_22/MaxPool:0', description="created by layer 'max_pooling2d_22'")
# out1 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 16), dtype=tf.float32, name=None), name='add_42/add:0', description="created by layer 'add_42'")
# shape of temp out:  KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='conv2d_119/BiasAdd:0', description="created by layer 'conv2d_119'")
# Skip1 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='add_43/add:0', description="created by layer 'add_43'")
# out2 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name=None), name='max_pooling2d_23/MaxPool:0', description="created by layer 'max_pooling2d_23'")
# out3 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name=None), name='add_44/add:0', description="created by layer 'add_44'")
# Skip2 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='add_45/add:0', description="created by layer 'add_45'")
# out8 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 64), dtype=tf.float32, name=None), name='max_pooling2d_24/MaxPool:0', description="created by layer 'max_pooling2d_24'")
# out5 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 64), dtype=tf.float32, name=None), name='add_46/add:0', description="created by layer 'add_46'")
# convvv KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='conv2d_127/BiasAdd:0', description="created by layer 'conv2d_127'")
# Skip3 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='add_47/add:0', description="created by layer 'add_47'")
# out6 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 128), dtype=tf.float32, name=None), name='max_pooling2d_25/MaxPool:0', description="created by layer 'max_pooling2d_25'")
# out7 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 128), dtype=tf.float32, name=None), name='add_48/add:0', description="created by layer 'add_48'")
# Skip4 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='add_49/add:0', description="created by layer 'add_49'")
# out8 dimensions is: KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 256), dtype=tf.float32, name=None), name='max_pooling2d_26/MaxPool:0', description="created by layer 'max_pooling2d_26'")
# Connnnnnnnnnv: KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 256), dtype=tf.float32, name=None), name='activation_51/Relu:0', description="created by layer 'activation_51'")

# %%
def upsample(x, scale, num_filters):
    def upsample_1(x, factor, **kwargs):
        """Sub-pixel convolution."""
        x = Conv2D(num_filters * (factor ** 2), 3, padding='same', **kwargs)(x)
        return (pixel_shuffle(scale=factor))(x)

    if scale == 2:
        x = upsample_1(x, 2)
    elif scale == 3:
        x = upsample_1(x, 3)
    elif scale == 4:
        x = upsample_1(x, 4)

    return x


def pixel_shuffle(scale):
    return lambda x: tf.nn.depth_to_space(x, scale)


ups1 = upsample(conv, 2, 256)
print('ups1:', ups1)
stack1 = concatenate([skip4, ups1])
# print(f'stack1: {stack1}')
# enc = tkl.Dropout(0.2)(stack1)
# enc = BatchNormalization()(conv)
enc = Conv2D(128, (3,3), padding='same')(stack1)
enc = Activation('relu')(enc)
# enc = tkl.Dropout(0.2)(enc)
enc = Conv2D(128, (3,3), padding='same')(enc)
enc = Activation('relu')(enc)
print(f'enc0: {enc}')

# enc = Activation('relu')(enc)

#2

ups2 = upsample(enc, 2, 64)
print('ups2:', ups2)
stack2 = concatenate([skip3, ups2])
# conv = tkl.Dropout(0.2)(ups2)
# enc = BatchNormalization()(conv)
enc = Conv2D(64, (3,3), padding='same')(stack2)
enc = Activation('relu')(enc)
enc = Conv2D(64, (3,3), padding='same')(enc)
# enc = Activation('relu')(enc)
enc = Activation('relu')(enc)
print('enc1:', enc)
#3

ups3 = upsample(enc, 2, 32)
print('ups3:', ups3)
stack3 = concatenate([skip2, ups3])
# enc = tkl.Dropout(0.2)(ups3)
# enc = BatchNormalization()(conv)
enc = Conv2D(32, (3,3), padding='same')(stack3)
enc = Activation('relu')(enc)
enc = Conv2D(32, (3,3), padding='same')(enc)
# enc = Activation('relu')(enc)
enc = Activation('relu')(enc)
print('enc2:', enc)
#4

ups4 = upsample(enc, 2, 16)
print('ups4:', ups4)
stack4 = concatenate([skip1, ups4])
# enc = BatchNormalization()(conv)
# enc = tkl.Dropout(0.2)(stack4)
enc = Conv2D(32, (3,3), padding='same')(stack4)
enc = Activation('relu')(enc)
# enc = tkl.Dropout(0.2)(enc)
enc = Conv2D(16, (3,3), padding='same')(enc)

# enc = Activation('relu')(enc)
# enc = Activation('relu')(enc)
print('enc3:', enc)
#5

ups5 = upsample(enc, 2, 16)
stack5 = concatenate([skip0, ups5])
# enc = tkl.Dropout(0.2)(stack5)
enc = Conv2D(3, (3,3), padding='same')(stack5)
enc = Activation('relu')(enc)
# enc = tkl.Dropout(0.2)(conv)
enc = Conv2D(3, (3,3), padding='same')(enc)
print('enc4:', enc)
enc = Activation('relu')(enc)
ups6 = upsample(enc, 2, 3)
print('ups6:', ups6)
output = Conv2D(3, (1,1), activation='sigmoid')(ups6)


print(output)

model = tf.keras.Model(inputs = [input_img], outputs = [output])
# Out:
# ups1: KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='tf.nn.depth_to_space_55/DepthToSpace:0', description="created by layer 'tf.nn.depth_to_space_55'")
# enc0: KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 128), dtype=tf.float32, name=None), name='activation_139/Relu:0', description="created by layer 'activation_139'")
# ups2: KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 64), dtype=tf.float32, name=None), name='tf.nn.depth_to_space_56/DepthToSpace:0', description="created by layer 'tf.nn.depth_to_space_56'")
# enc1: KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 64), dtype=tf.float32, name=None), name='activation_141/Relu:0', description="created by layer 'activation_141'")
# ups3: KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name=None), name='tf.nn.depth_to_space_57/DepthToSpace:0', description="created by layer 'tf.nn.depth_to_space_57'")
# enc2: KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name=None), name='activation_143/Relu:0', description="created by layer 'activation_143'")
# ups4: KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 16), dtype=tf.float32, name=None), name='tf.nn.depth_to_space_58/DepthToSpace:0', description="created by layer 'tf.nn.depth_to_space_58'")
# enc3: KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 16), dtype=tf.float32, name=None), name='conv2d_301/BiasAdd:0', description="created by layer 'conv2d_301'")
# enc4: KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='conv2d_304/BiasAdd:0', description="created by layer 'conv2d_304'")
# ups6: KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), name='tf.nn.depth_to_space_60/DepthToSpace:0', description="created by layer 'tf.nn.depth_to_space_60'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), name='conv2d_306/Sigmoid:0', description="created by layer 'conv2d_306'")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d_90 (ZeroPadding  (None, 518, 518, 3)  0          ['image[0][0]']
#  2D)
#
#  conv2d_114 (Conv2D)            (None, 256, 256, 16  2368        ['zero_padding2d_90[0][0]']
#                                 )
#
#  max_pooling2d_22 (MaxPooling2D  (None, 128, 128, 16  0          ['conv2d_114[0][0]']
#  )                              )
#
#  zero_padding2d_91 (ZeroPadding  (None, 130, 130, 16  0          ['max_pooling2d_22[0][0]']
#  2D)                            )
#
#  conv2d_115 (Conv2D)            (None, 128, 128, 16  2320        ['zero_padding2d_91[0][0]']
#                                 )
#
#  activation_42 (Activation)     (None, 128, 128, 16  0           ['conv2d_115[0][0]']
#                                 )
#
#  zero_padding2d_92 (ZeroPadding  (None, 130, 130, 16  0          ['activation_42[0][0]']
#  2D)                            )
#
#  conv2d_116 (Conv2D)            (None, 128, 128, 16  2320        ['zero_padding2d_92[0][0]']
#                                 )
#
#  add_42 (Add)                   (None, 128, 128, 16  0           ['conv2d_116[0][0]',
#                                 )                                 'max_pooling2d_22[0][0]']
#
#  zero_padding2d_93 (ZeroPadding  (None, 130, 130, 16  0          ['add_42[0][0]']
#  2D)                            )
#
#  conv2d_117 (Conv2D)            (None, 128, 128, 32  4640        ['zero_padding2d_93[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 128, 128, 32  0           ['conv2d_117[0][0]']
#                                 )
#
#  zero_padding2d_94 (ZeroPadding  (None, 130, 130, 32  0          ['activation_43[0][0]']
#  2D)                            )
#
#  conv2d_118 (Conv2D)            (None, 128, 128, 32  9248        ['zero_padding2d_94[0][0]']
#                                 )
#
#  conv2d_119 (Conv2D)            (None, 128, 128, 32  544         ['add_42[0][0]']
#                                 )
#
#  add_43 (Add)                   (None, 128, 128, 32  0           ['conv2d_118[0][0]',
#                                 )                                 'conv2d_119[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 64, 64, 32)  0           ['add_43[0][0]']
#  )
#
#  zero_padding2d_95 (ZeroPadding  (None, 66, 66, 32)  0           ['max_pooling2d_23[0][0]']
#  2D)
#
#  conv2d_120 (Conv2D)            (None, 64, 64, 32)   9248        ['zero_padding2d_95[0][0]']
#
#  activation_44 (Activation)     (None, 64, 64, 32)   0           ['conv2d_120[0][0]']
#
#  zero_padding2d_96 (ZeroPadding  (None, 66, 66, 32)  0           ['activation_44[0][0]']
#  2D)
#
#  conv2d_121 (Conv2D)            (None, 64, 64, 32)   9248        ['zero_padding2d_96[0][0]']
#
#  add_44 (Add)                   (None, 64, 64, 32)   0           ['conv2d_121[0][0]',
#                                                                   'max_pooling2d_23[0][0]']
#
#  zero_padding2d_97 (ZeroPadding  (None, 66, 66, 32)  0           ['add_44[0][0]']
#  2D)
#
#  conv2d_122 (Conv2D)            (None, 64, 64, 64)   18496       ['zero_padding2d_97[0][0]']
#
#  activation_45 (Activation)     (None, 64, 64, 64)   0           ['conv2d_122[0][0]']
#
#  zero_padding2d_98 (ZeroPadding  (None, 66, 66, 64)  0           ['activation_45[0][0]']
#  2D)
#
#  conv2d_123 (Conv2D)            (None, 64, 64, 64)   36928       ['zero_padding2d_98[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 64, 64, 64)   2112        ['add_44[0][0]']
#
#  add_45 (Add)                   (None, 64, 64, 64)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_124[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 32, 32, 64)  0           ['add_45[0][0]']
#  )
#
#  zero_padding2d_99 (ZeroPadding  (None, 34, 34, 64)  0           ['max_pooling2d_24[0][0]']
#  2D)
#
#  conv2d_125 (Conv2D)            (None, 32, 32, 64)   36928       ['zero_padding2d_99[0][0]']
#
#  activation_46 (Activation)     (None, 32, 32, 64)   0           ['conv2d_125[0][0]']
#
#  zero_padding2d_100 (ZeroPaddin  (None, 34, 34, 64)  0           ['activation_46[0][0]']
#  g2D)
#
#  conv2d_126 (Conv2D)            (None, 32, 32, 64)   36928       ['zero_padding2d_100[0][0]']
#
#  add_46 (Add)                   (None, 32, 32, 64)   0           ['conv2d_126[0][0]',
#                                                                   'max_pooling2d_24[0][0]']
#
#  zero_padding2d_101 (ZeroPaddin  (None, 34, 34, 64)  0           ['add_46[0][0]']
#  g2D)
#
#  conv2d_127 (Conv2D)            (None, 32, 32, 128)  73856       ['zero_padding2d_101[0][0]']
#
#  activation_47 (Activation)     (None, 32, 32, 128)  0           ['conv2d_127[0][0]']
#
#  zero_padding2d_102 (ZeroPaddin  (None, 34, 34, 128)  0          ['activation_47[0][0]']
#  g2D)
#
#  conv2d_128 (Conv2D)            (None, 32, 32, 128)  147584      ['zero_padding2d_102[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_128[0][0]']
#  rmalization)
#
#  conv2d_129 (Conv2D)            (None, 32, 32, 128)  8320        ['add_46[0][0]']
#
#  add_47 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_4[0][0]',
#                                                                   'conv2d_129[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 16, 16, 128)  0          ['add_47[0][0]']
#  )
#
#  zero_padding2d_103 (ZeroPaddin  (None, 18, 18, 128)  0          ['max_pooling2d_25[0][0]']
#  g2D)
#
#  conv2d_130 (Conv2D)            (None, 16, 16, 128)  147584      ['zero_padding2d_103[0][0]']
#
#  activation_48 (Activation)     (None, 16, 16, 128)  0           ['conv2d_130[0][0]']
#
#  zero_padding2d_104 (ZeroPaddin  (None, 18, 18, 128)  0          ['activation_48[0][0]']
#  g2D)
#
#  conv2d_131 (Conv2D)            (None, 16, 16, 128)  147584      ['zero_padding2d_104[0][0]']
#
#  add_48 (Add)                   (None, 16, 16, 128)  0           ['conv2d_131[0][0]',
#                                                                   'max_pooling2d_25[0][0]']
#
#  zero_padding2d_105 (ZeroPaddin  (None, 18, 18, 128)  0          ['add_48[0][0]']
#  g2D)
#
#  conv2d_132 (Conv2D)            (None, 16, 16, 256)  295168      ['zero_padding2d_105[0][0]']
#
#  activation_49 (Activation)     (None, 16, 16, 256)  0           ['conv2d_132[0][0]']
#
#  zero_padding2d_106 (ZeroPaddin  (None, 18, 18, 256)  0          ['activation_49[0][0]']
#  g2D)
#
#  conv2d_133 (Conv2D)            (None, 16, 16, 256)  590080      ['zero_padding2d_106[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 16, 16, 256)  33024       ['add_48[0][0]']
#
#  add_49 (Add)                   (None, 16, 16, 256)  0           ['conv2d_133[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 8, 8, 256)   0           ['add_49[0][0]']
#  )
#
#  activation_50 (Activation)     (None, 8, 8, 256)    0           ['max_pooling2d_26[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 8, 8, 256)    590080      ['activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 8, 8, 256)    0           ['conv2d_135[0][0]']
#
# ==================================================================================================
# Total params: 2,205,120
# Trainable params: 2,204,864
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# ### Compiling the model:

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay

# optim_edsr = Adam(learning_rate=PiecewiseConstantDecay(boundaries=[200000], values=[1e-4, 5e-5]))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['accuracy'])

# %% [markdown]
# ### Training the model:

# %%
history = model.fit(train_generator,
                    validation_data = val_generator,
                    use_multiprocessing = True,
                    workers = 6, epochs=10)
# Out:
# Epoch 1/10
# Process Keras_worker_ForkPoolWorker-17:
# Traceback (most recent call last):
# Process Keras_worker_ForkPoolWorker-15:
# Process Keras_worker_ForkPoolWorker-18:
# Process Keras_worker_ForkPoolWorker-16:
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Keras_worker_ForkPoolWorker-14:
# Traceback (most recent call last):
# Process Keras_worker_ForkPoolWorker-13:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.7.0

# %%
model.save('1024_Denoising.h5')

# %% [markdown]
# ### Testing the model on the test set:

# %%
# path = '/kaggle/input/stanford-cars-dataset/cars_test/cars_test/'
# print(len(test_data))
evaluation_set = test_filenames[1]
# test_img_path = test_filenames[104]
# test_img = cv2.imread(test_img_path)
# test_img = cv2.resize(test_img, (WIDTH, HEIGHT))
# test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
# test_img = random_noise(test_img, mode = 's&p', amount = 0.2)
# plt.imshow(test_img)
evaluation_set
# Out:
# '/content/gdrive/MyDrive/lfw/Milton_Wynants/Milton_Wynants_0001.jpg'

# %%
eval_set = []
# for i in range(32):
#     img = cv2.imread(evaluation_set[i])
#     img = cv2.resize(img, (WIDTH, HEIGHT))
#     img = random_noise(img, mode = 's&p', amount=0.2)
#     eval_set.append(img)
# eval_set = np.array(eval_set)
# eval_set[1].shape
path = evaluation_set

img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (WIDTH, HEIGHT))
img = random_noise(img, mode = 's&p', amount=0.2)
eval_set.append(img)
img = tf.expand_dims(img, axis=0)


# testst = eval_set[1][0,:,:]
# testst.shape
# tessssst = cv2.resize(eval_set[1], (256,256))
# resized_image = tf.image.resize(eval_set[1], [256, 256])
# resized_image.shape
predicted = model.predict(img)

# %%
for j in range(3):
  predicted_ = cv2.resize(predicted[j*8], (500,500))
  predicted_ = cv2.cvtColor(predicted_, cv2.COLOR_BGR2RGB)
  fig, ax = plt.subplots(1,9, figsize = (20,20))
  original = cv2.imread(evaluation_set[j*8])
  original = cv2.resize(original, (500, 500))
  original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
  noisy_orig = random_noise(original, mode = 's&p', amount=0.2)
  noisy_orig = cv2.resize(noisy_orig, (500,500))
  ax[0].imshow(predicted_)
  ax[0].set_title('Predicted Image')
  ax[1].imshow(original)
  ax[1].set_title('Original Image')
  ax[2].imshow(noisy_orig)
  ax[2].set_title('Noisy Image')

# %%
predicted = tf.squeeze(predicted, axis=0)

predicted = np.array(predicted) * 255
predicted = predicted.astype(np.uint8)
# predicted = tf.image.adjust_contrast(predicted, )

plt.imshow(predicted)

# %%
# predicted = tf.squeeze(predicted, axis=0)

# predicted = np.array(predicted) * 255
predicted = cv2.cvtColor(predicted, cv2.COLOR_BGR2RGB)
plt.imshow(predicted)

# %%
predicted.shape
# Out:
# (256, 256, 3)

# %%
test_img_path = test_filenames[1]
test_img = cv2.imread(test_img_path)
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
test_img = cv2.resize(test_img, (WIDTH, HEIGHT))
plt.imshow(test_img)

# %%
model = tf.keras.models.load_model('/content/FaceUnetDenoising.h5')

# %%
path = '/content/Abbas_Kiarostami_0001.jpg'

img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (256, 256))
img = random_noise(img, mode = 'gaussian')
# eval_set.append(img)
img = tf.expand_dims(img, axis=0)
predicted = model.predict(img)

# %%
predicted = tf.squeeze(predicted)
# predicted = cv2.cvtColor(predicted, cv2.COLOR_BGR2RGB)
plt.imshow(predicted)

# %%
img = tf.squeeze(img)

plt.imshow(img)

# %%
# for j in range(3):
predicted = np.array(predicted)
predicted = cv2.resize(predicted, (500,500))
predicted = cv2.cvtColor(predicted, cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots(1,3, figsize = (20,20))
original = cv2.imread(path)
original = cv2.resize(original, (500, 500))
original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
noisy_orig = random_noise(originalmode = 's&p', amount=0.2)
noisy_orig = cv2.resize(noisy_orig, (500,500))
ax[0].imshow(predicted)
ax[0].set_title('Predicted Image')
ax[1].imshow(original)
ax[1].set_title('Original Image')
ax[2].imshow(noisy_orig)
ax[2].set_title('Noisy Image')
# Out:
# Text(0.5, 1.0, 'Noisy Image')
